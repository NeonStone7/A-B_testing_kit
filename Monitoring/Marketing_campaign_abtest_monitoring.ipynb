# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
# File location and type
file_location = "/FileStore/tables/all_test_data.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

schema = StructType([
    StructField('user_id', StringType(), True),
    StructField('date', DateType(), True),
    StructField('ctr', DoubleType(), True),
    StructField('revenue', DoubleType(), True),
    StructField('is_test_group', StringType(), True),
    
])


# The applied options are for CSV files. For other file types, these will be ignored.
main_metrics = (spark.read.format(file_type) 
    .schema(schema)
  .option("header", True) 
  .load(file_location)
  )

# Identify test and control
main_metrics = main_metrics.withColumn('is_test_group', when(col('is_test_group')==1, 'test').otherwise('control'))

main_metrics.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# File location and type
file_location = "/FileStore/tables/all_test_data_dau.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

schema = StructType([
    StructField('date', DateType(), True),
    StructField('daily_users_num', DoubleType(), True)
])


# The applied options are for CSV files. For other file types, these will be ignored.
dau = (spark.read.format(file_type) 
    .schema(schema)
  .option("header", True) 
  .load(file_location)
  )

dau.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
